# %% [markdown]
# #LIFO

# %%
# Average wait plot
# Producer Process 2, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('LIFO: Producer Process 2, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [13.339140, 10.144312, 10.381437, 7.236977, 7.261243])
plt.plot([2, 4, 6, 8, 10], [13.339140, 10.144312, 10.381437, 7.236977, 7.261243], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("LIFO_demo2_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('LIFO: Producer Process 2, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000147, 0.000177, 0.000159, 0.000131, 0.000190])
plt.plot([2, 4, 6, 8, 10], [0.000147, 0.000177, 0.000159, 0.000131, 0.000190], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("LIFO_demo2_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 4, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('LIFO: Producer Process 4, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [12.783920, 16.711742, 11.864747, 10.844989, 12.865334])
plt.plot([2, 4, 6, 8, 10], [12.783920, 16.711742, 11.864747, 10.844989, 12.865334], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("LIFO_demo4_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('LIFO: Producer Process 4, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000195, 0.000145, 0.000199, 0.000225, 0.000253])
plt.plot([2, 4, 6, 8, 10], [0.000195, 0.000145, 0.000199, 0.000225, 0.000253], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("LIFO_demo4_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 6, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('LIFO: Producer Process 6, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [9.863209, 16.352345, 13.018699, 13.823384, 11.763546])
plt.plot([2, 4, 6, 8, 10], [9.863209, 16.352345, 13.018699, 13.823384, 11.763546], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("LIFO_demo6_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('LIFO: Producer Process 6, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000280, 0.000182, 0.000180, 0.000206, 0.000347])
plt.plot([2, 4, 6, 8, 10], [0.000280, 0.000182, 0.000180, 0.000206, 0.000347], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("LIFO_demo6_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 8, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('LIFO: Producer Process 8, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [12.419781, 14.737928, 15.754559, 16.141388, 15.287356])
plt.plot([2, 4, 6, 8, 10], [12.419781, 14.737928, 15.754559, 16.141388, 15.287356], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("LIFO_demo8_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('LIFO: Producer Process 8, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000225, 0.000178, 0.000212, 0.000200, 0.000205])
plt.plot([2, 4, 6, 8, 10], [0.000225, 0.000178, 0.000212, 0.000200, 0.000205], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("LIFO_demo8_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 10, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('LIFO: Producer Process 10, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [14.298196, 15.555996, 14.486377, 14.143488, 13.721283])
plt.plot([2, 4, 6, 8, 10], [14.298196, 15.555996, 14.486377, 14.143488, 13.721283], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("LIFO_demo10_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('LIFO: Producer Process 10, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000185, 0.000191, 0.000212, 0.000282, 0.000233])
plt.plot([2, 4, 6, 8, 10], [0.000185, 0.000191, 0.000212, 0.000282, 0.000233], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("LIFO_demo10_Waiting.pdf", bbox_inches='tight')

# %% [markdown]
# #FIFO

# %%
# Average wait plot
# Producer Process 2, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('FIFO: Producer Process 2, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [7.920863, 11.702671, 11.785443, 10.230080, 12.479856])
plt.plot([2, 4, 6, 8, 10], [7.920863, 11.702671, 11.785443, 10.230080, 12.479856], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("FIFO_demo2_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('FIFO: Producer Process 2, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000163, 0.000163, 0.000142, 0.000153, 0.000156])
plt.plot([2, 4, 6, 8, 10], [0.000163, 0.000163, 0.000142, 0.000153, 0.000156], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("FIFO_demo2_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 4, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

f = plt.figure()
plt.title('FIFO: Producer Process 4, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [18.265491, 11.656758, 15.198689, 19.781736, 12.827639])
plt.plot([2, 4, 6, 8, 10], [18.265491, 11.656758, 15.198689, 19.781736, 12.827639], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("FIFO_demo4_Execution.pdf", bbox_inches='tight')



f = plt.figure()
plt.title('FIFO: Producer Process 4, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], [0.000164, 0.000195, 0.000175, 0.000170, 0.000195])
plt.plot([2, 4, 6, 8, 10], [0.000164, 0.000195, 0.000175, 0.000170, 0.000195], 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("FIFO_demo4_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 6, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

Execution = [16.074550, 14.736517, 14.416196, 14.110809, 12.264148]
f = plt.figure()
plt.title('FIFO: Producer Process 6, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Execution)
plt.plot([2, 4, 6, 8, 10], Execution, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("FIFO_demo6_Execution.pdf", bbox_inches='tight')


Waiting = [0.000188,  0.000178, 0.000237, 0.000200, 0.000296]
f = plt.figure()
plt.title('FIFO: Producer Process 6, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Waiting)
plt.plot([2, 4, 6, 8, 10], Waiting, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("FIFO_demo6_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 8, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

Execution = [10.406340, 14.873261, 15.134314, 13.728350, 13.933873]
Waiting = [0.000185,  0.000233, 0.000187, 0.000273, 0.000203]

f = plt.figure()
plt.title('FIFO: Producer Process 8, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Execution)
plt.plot([2, 4, 6, 8, 10], Execution, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("FIFO_demo8_Execution.pdf", bbox_inches='tight')


f = plt.figure()
plt.title('FIFO: Producer Process 8, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Waiting)
plt.plot([2, 4, 6, 8, 10], Waiting, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("FIFO_demo8_Waiting.pdf", bbox_inches='tight')

# %%
# Average wait plot
# Producer Process 10, consumer thread [2, 4, 6, 8, 10]

import matplotlib.pyplot as plt

# Execution time values for Process 10
Execution = [16.549124, 18.011919, 15.017493, 17.288976, 14.102517]

# Waiting time values for Process 10
Waiting = [0.000250,  0.000185, 0.000187, 0.000232, 0.000230]

f = plt.figure()
plt.title('FIFO: Producer Process 8, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Execution)
plt.plot([2, 4, 6, 8, 10], Execution, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Execution Time'})
plt.show()
f.savefig("FIFO_demo10_Execution.pdf", bbox_inches='tight')


f = plt.figure()
plt.title('FIFO: Producer Process 10, consumer thread [2, 4, 6, 8, 10]')
plt.plot([2, 4, 6, 8, 10], Waiting)
plt.plot([2, 4, 6, 8, 10], Waiting, 'bo')
plt.xlabel("Consumer Threads")
plt.ylabel("Time (in nanosecond)")
plt.legend({'Average Waiting Time'})
plt.show()
f.savefig("FIFO_demo10_Waiting.pdf", bbox_inches='tight')
